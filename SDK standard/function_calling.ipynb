# %% [markdown]
# # Function Calling
# *Function Calling* é um recurso usado em LLM's que permite ao modelo chamar funções
# do seu código de maneira estruturada, em vez de responder apenas com texto livre.
#
# Então, é uma estratégia que fornece ao LLM um "esqueleto" (normalmente me JSON Schema)
# descrevendo:
#
# * Nome da função;
# * O que ela faz;
# * Quais argumentos aceita;
# * Tipo/formato dos argumentos;
# * Campos obrigatórios;
#
# Isso guia o modelo a:
#
# * Entender quando usar a função;
# * Montagem correta dos argumentos;
# * Devolver uma saída estruturada e válida, reduzindo os erros;
#
# OBS.: o LLM não excecuta a função. Ele apenas decide que *função* chamar e com
# *_quais parâmetros_*. Quem executa a função é o sistema.
#
# ### Exemplo Simples

# %%
#funcao do seu backend
def create_user(name:str, email:str)->dict:
    return {'id':1, 'name':name}

# %%
#resposta do LLM
{
  "name": "criar_usuario",
  "arguments": {
    "nome": "Ana",
    "email": "ana@email.com"
}
}
# Out:
# {'name': 'criar_usuario',
#  'arguments': {'nome': 'Ana', 'email': 'ana@email.com'}}

# %% [markdown]
# ## Porque isso é importante?
# ### Segurança
# * O LLM não tem acesso direto a banco, filesystem ou APIs
#
# * Você controla quais funções existem
#
# * Você valida quando e como executar
#
# ### Controle
# * Você pode bloquear chamadas indevidas
#
# * Pode validar parâmetros
#
# * Pode logar tudo

# %%
import os, json
from dotenv import dotenv_values
import requests
from openai import OpenAI

config = dotenv_values('../.env')
openai_api_key = config['OPENAI_API_KEY']
open_weather_key = config['OPEN_WEATHER_KEY']

# %% [markdown]
# ## Testando API Open Weather

# %%
lat = -6.77168
lon = -38.0479
url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
) 

resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
result = json.loads(resp.content)
result
# Out:
# {'lat': -6.7717,
#  'lon': -38.0479,
#  'timezone': 'America/Fortaleza',
#  'timezone_offset': -10800,
#  'current': {'dt': 1769110027,
#   'sunrise': 1769070618,
#   'sunset': 1769115412,
#   'temp': 37.14,
#   'feels_like': 34.78,
#   'pressure': 1005,
#   'humidity': 15,
#   'dew_point': 6.22,
#   'uvi': 1.64,
#   'clouds': 11,
#   'visibility': 10000,
#   'wind_speed': 5.03,
#   'wind_deg': 84,
#   'wind_gust': 5.75,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'algumas nuvens',
#     'icon': '02d'}]},
#  'minutely': [{'dt': 1769110080, 'precipitation': 0},
#   {'dt': 1769110140, 'precipitation': 0},
#   {'dt': 1769110200, 'precipitation': 0},
#   {'dt': 1769110260, 'precipitation': 0},
#   {'dt': 1769110320, 'precipitation': 0},
#   {'dt': 1769110380, 'precipitation': 0},
#   {'dt': 1769110440, 'precipitation': 0},
#   {'dt': 1769110500, 'precipitation': 0},
#   {'dt': 1769110560, 'precipitation': 0},
#   {'dt': 1769110620, 'precipitation': 0},
#   {'dt': 1769110680, 'precipitation': 0},
#   {'dt': 1769110740, 'precipitation': 0},
#   {'dt': 1769110800, 'precipitation': 0},
#   {'dt': 1769110860, 'precipitation': 0},
#   {'dt': 1769110920, 'precipitation': 0},
#   {'dt': 1769110980, 'precipitation': 0},
#   {'dt': 1769111040, 'precipitation': 0},
#   {'dt': 1769111100, 'precipitation': 0},
#   {'dt': 1769111160, 'precipitation': 0},
#   {'dt': 1769111220, 'precipitation': 0},
#   {'dt': 1769111280, 'precipitation': 0},
#   {'dt': 1769111340, 'precipitation': 0},
#   {'dt': 1769111400, 'precipitation': 0},
#   {'dt': 1769111460, 'precipitation': 0},
#   {'dt': 1769111520, 'precipitation': 0},
#   {'dt': 1769111580, 'precipitation': 0},
#   {'dt': 1769111640, 'precipitation': 0},
#   {'dt': 1769111700, 'precipitation': 0},
#   {'dt': 1769111760, 'precipitation': 0},
#   {'dt': 1769111820, 'precipitation': 0},
#   {'dt': 1769111880, 'precipitation': 0},
#   {'dt': 1769111940, 'precipitation': 0},
#   {'dt': 1769112000, 'precipitation': 0},
#   {'dt': 1769112060, 'precipitation': 0},
#   {'dt': 1769112120, 'precipitation': 0},
#   {'dt': 1769112180, 'precipitation': 0},
#   {'dt': 1769112240, 'precipitation': 0},
#   {'dt': 1769112300, 'precipitation': 0},
#   {'dt': 1769112360, 'precipitation': 0},
#   {'dt': 1769112420, 'precipitation': 0},
#   {'dt': 1769112480, 'precipitation': 0},
#   {'dt': 1769112540, 'precipitation': 0},
#   {'dt': 1769112600, 'precipitation': 0},
#   {'dt': 1769112660, 'precipitation': 0},
#   {'dt': 1769112720, 'precipitation': 0},
#   {'dt': 1769112780, 'precipitation': 0},
#   {'dt': 1769112840, 'precipitation': 0},
#   {'dt': 1769112900, 'precipitation': 0},
#   {'dt': 1769112960, 'precipitation': 0},
#   {'dt': 1769113020, 'precipitation': 0},
#   {'dt': 1769113080, 'precipitation': 0},
#   {'dt': 1769113140, 'precipitation': 0},
#   {'dt': 1769113200, 'precipitation': 0},
#   {'dt': 1769113260, 'precipitation': 0},
#   {'dt': 1769113320, 'precipitation': 0},
#   {'dt': 1769113380, 'precipitation': 0},
#   {'dt': 1769113440, 'precipitation': 0},
#   {'dt': 1769113500, 'precipitation': 0},
#   {'dt': 1769113560, 'precipitation': 0},
#   {'dt': 1769113620, 'precipitation': 0}],
#  'hourly': [{'dt': 1769108400,
#    'temp': 37.14,
#    'feels_like': 34.78,
#    'pressure': 1005,
#    'humidity': 15,
#    'dew_point': 6.22,
#    'uvi': 1.64,
#    'clouds': 11,
#    'visibility': 10000,
#    'wind_speed': 5.03,
#    'wind_deg': 84,
#    'wind_gust': 5.75,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769112000,
#    'temp': 36.98,
#    'feels_like': 34.74,
#    'pressure': 1005,
#    'humidity': 16,
#    'dew_point': 7.03,
#    'uvi': 0.3,
#    'clouds': 11,
#    'visibility': 10000,
#    'wind_speed': 4.69,
#    'wind_deg': 81,
#    'wind_gust': 5.65,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769115600,
#    'temp': 35.28,
#    'feels_like': 33.03,
#    'pressure': 1005,
#    'humidity': 17,
#    'dew_point': 6.55,
#    'uvi': 0,
#    'clouds': 10,
#    'visibility': 10000,
#    'wind_speed': 3.16,
#    'wind_deg': 67,
#    'wind_gust': 3.64,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769119200,
#    'temp': 33.19,
#    'feels_like': 31.13,
#    'pressure': 1006,
#    'humidity': 20,
#    'dew_point': 7.23,
#    'uvi': 0,
#    'clouds': 10,
#    'visibility': 10000,
#    'wind_speed': 3.1,
#    'wind_deg': 55,
#    'wind_gust': 3.28,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769122800,
#    'temp': 31.08,
#    'feels_like': 29.42,
#    'pressure': 1007,
#    'humidity': 25,
#    'dew_point': 8.75,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 3.47,
#    'wind_deg': 47,
#    'wind_gust': 8.72,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769126400,
#    'temp': 29.07,
#    'feels_like': 28.59,
#    'pressure': 1009,
#    'humidity': 39,
#    'dew_point': 13.76,
#    'uvi': 0,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 7.92,
#    'wind_deg': 52,
#    'wind_gust': 12.88,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769130000,
#    'temp': 27.74,
#    'feels_like': 27.78,
#    'pressure': 1010,
#    'humidity': 45,
#    'dew_point': 14.96,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 6.05,
#    'wind_deg': 62,
#    'wind_gust': 10.43,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769133600,
#    'temp': 26.48,
#    'feels_like': 26.48,
#    'pressure': 1011,
#    'humidity': 54,
#    'dew_point': 16.54,
#    'uvi': 0,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 5.53,
#    'wind_deg': 78,
#    'wind_gust': 9.51,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769137200,
#    'temp': 25.62,
#    'feels_like': 25.7,
#    'pressure': 1011,
#    'humidity': 56,
#    'dew_point': 16.33,
#    'uvi': 0,
#    'clouds': 19,
#    'visibility': 10000,
#    'wind_speed': 4.68,
#    'wind_deg': 78,
#    'wind_gust': 8.45,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769140800,
#    'temp': 24.64,
#    'feels_like': 24.65,
#    'pressure': 1011,
#    'humidity': 57,
#    'dew_point': 15.79,
#    'uvi': 0,
#    'clouds': 16,
#    'visibility': 10000,
#    'wind_speed': 3.89,
#    'wind_deg': 66,
#    'wind_gust': 7.49,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769144400,
#    'temp': 23.7,
#    'feels_like': 23.69,
#    'pressure': 1010,
#    'humidity': 60,
#    'dew_point': 15.63,
#    'uvi': 0,
#    'clouds': 15,
#    'visibility': 10000,
#    'wind_speed': 2.74,
#    'wind_deg': 54,
#    'wind_gust': 5.39,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769148000,
#    'temp': 23,
#    'feels_like': 23,
#    'pressure': 1011,
#    'humidity': 63,
#    'dew_point': 15.72,
#    'uvi': 0,
#    'clouds': 15,
#    'visibility': 10000,
#    'wind_speed': 2.44,
#    'wind_deg': 68,
#    'wind_gust': 3.75,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769151600,
#    'temp': 22.58,
#    'feels_like': 22.64,
#    'pressure': 1011,
#    'humidity': 67,
#    'dew_point': 16.17,
#    'uvi': 0,
#    'clouds': 20,
#    'visibility': 10000,
#    'wind_speed': 2.4,
#    'wind_deg': 74,
#    'wind_gust': 4.08,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769155200,
#    'temp': 22.23,
#    'feels_like': 22.41,
#    'pressure': 1011,
#    'humidity': 73,
#    'dew_point': 17.22,
#    'uvi': 0,
#    'clouds': 20,
#    'visibility': 10000,
#    'wind_speed': 2.4,
#    'wind_deg': 85,
#    'wind_gust': 4.15,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1769158800,
#    'temp': 22.73,
#    'feels_like': 23.04,
#    'pressure': 1012,
#    'humidity': 76,
#    'dew_point': 18.28,
#    'uvi': 0.25,
#    'clouds': 24,
#    'visibility': 10000,
#    'wind_speed': 2.5,
#    'wind_deg': 94,
#    'wind_gust': 7.17,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769162400,
#    'temp': 25.11,
#    'feels_like': 25.37,
#    'pressure': 1012,
#    'humidity': 65,
#    'dew_point': 18.15,
#    'uvi': 1.45,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 4.04,
#    'wind_deg': 111,
#    'wind_gust': 6.44,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769166000,
#    'temp': 27.5,
#    'feels_like': 28.3,
#    'pressure': 1013,
#    'humidity': 55,
#    'dew_point': 17.63,
#    'uvi': 4.09,
#    'clouds': 53,
#    'visibility': 10000,
#    'wind_speed': 4.81,
#    'wind_deg': 109,
#    'wind_gust': 6.06,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769169600,
#    'temp': 29.46,
#    'feels_like': 29.88,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 17.22,
#    'uvi': 7.43,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 5.13,
#    'wind_deg': 95,
#    'wind_gust': 5.76,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769173200,
#    'temp': 31.05,
#    'feels_like': 31.13,
#    'pressure': 1012,
#    'humidity': 41,
#    'dew_point': 16.57,
#    'uvi': 11.08,
#    'clouds': 77,
#    'visibility': 10000,
#    'wind_speed': 5.35,
#    'wind_deg': 88,
#    'wind_gust': 5.52,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769176800,
#    'temp': 32.75,
#    'feels_like': 32.46,
#    'pressure': 1011,
#    'humidity': 35,
#    'dew_point': 15.57,
#    'uvi': 13.84,
#    'clouds': 44,
#    'visibility': 10000,
#    'wind_speed': 4.67,
#    'wind_deg': 88,
#    'wind_gust': 5.25,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769180400,
#    'temp': 34.52,
#    'feels_like': 33.99,
#    'pressure': 1010,
#    'humidity': 30,
#    'dew_point': 14.79,
#    'uvi': 13.93,
#    'clouds': 29,
#    'visibility': 10000,
#    'wind_speed': 4.13,
#    'wind_deg': 94,
#    'wind_gust': 4.96,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769184000,
#    'temp': 35.76,
#    'feels_like': 35.13,
#    'pressure': 1009,
#    'humidity': 27,
#    'dew_point': 14.09,
#    'uvi': 11.9,
#    'clouds': 23,
#    'visibility': 10000,
#    'wind_speed': 3.73,
#    'wind_deg': 91,
#    'wind_gust': 4.94,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769187600,
#    'temp': 36.61,
#    'feels_like': 35.67,
#    'pressure': 1008,
#    'humidity': 24,
#    'dew_point': 13.25,
#    'uvi': 8.26,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 3.61,
#    'wind_deg': 74,
#    'wind_gust': 4.86,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769191200,
#    'temp': 37.13,
#    'feels_like': 35.95,
#    'pressure': 1007,
#    'humidity': 22,
#    'dew_point': 12.17,
#    'uvi': 4.46,
#    'clouds': 37,
#    'visibility': 10000,
#    'wind_speed': 4.18,
#    'wind_deg': 55,
#    'wind_gust': 5.57,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769194800,
#    'temp': 37.24,
#    'feels_like': 35.69,
#    'pressure': 1006,
#    'humidity': 20,
#    'dew_point': 10.83,
#    'uvi': 1.67,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 4.74,
#    'wind_deg': 50,
#    'wind_gust': 5.92,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769198400,
#    'temp': 36.61,
#    'feels_like': 34.76,
#    'pressure': 1006,
#    'humidity': 19,
#    'dew_point': 9.17,
#    'uvi': 0.31,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 5,
#    'wind_deg': 55,
#    'wind_gust': 6.17,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769202000,
#    'temp': 32.89,
#    'feels_like': 31.07,
#    'pressure': 1007,
#    'humidity': 23,
#    'dew_point': 9.33,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 3.39,
#    'wind_deg': 52,
#    'wind_gust': 4.34,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769205600,
#    'temp': 30.52,
#    'feels_like': 29.02,
#    'pressure': 1008,
#    'humidity': 27,
#    'dew_point': 9.56,
#    'uvi': 0,
#    'clouds': 51,
#    'visibility': 10000,
#    'wind_speed': 2.93,
#    'wind_deg': 53,
#    'wind_gust': 3.06,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769209200,
#    'temp': 29.63,
#    'feels_like': 28.35,
#    'pressure': 1009,
#    'humidity': 29,
#    'dew_point': 9.71,
#    'uvi': 0,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 3.69,
#    'wind_deg': 37,
#    'wind_gust': 7.94,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769212800,
#    'temp': 28.16,
#    'feels_like': 27.95,
#    'pressure': 1010,
#    'humidity': 42,
#    'dew_point': 14.13,
#    'uvi': 0,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 6.66,
#    'wind_deg': 45,
#    'wind_gust': 11.86,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769216400,
#    'temp': 26.29,
#    'feels_like': 26.29,
#    'pressure': 1012,
#    'humidity': 55,
#    'dew_point': 16.69,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.2,
#    'wind_deg': 58,
#    'wind_gust': 9.22,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769220000,
#    'temp': 26.01,
#    'feels_like': 26.01,
#    'pressure': 1012,
#    'humidity': 62,
#    'dew_point': 18.16,
#    'uvi': 0,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 4.34,
#    'wind_deg': 67,
#    'wind_gust': 8.48,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769223600,
#    'temp': 25.65,
#    'feels_like': 25.99,
#    'pressure': 1012,
#    'humidity': 66,
#    'dew_point': 19.05,
#    'uvi': 0,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 4.78,
#    'wind_deg': 71,
#    'wind_gust': 8.43,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769227200,
#    'temp': 24.99,
#    'feels_like': 25.37,
#    'pressure': 1011,
#    'humidity': 70,
#    'dew_point': 19.17,
#    'uvi': 0,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 3.95,
#    'wind_deg': 76,
#    'wind_gust': 7.71,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769230800,
#    'temp': 24.46,
#    'feels_like': 24.84,
#    'pressure': 1011,
#    'humidity': 72,
#    'dew_point': 19.16,
#    'uvi': 0,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 3.44,
#    'wind_deg': 79,
#    'wind_gust': 7.33,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769234400,
#    'temp': 23.88,
#    'feels_like': 24.26,
#    'pressure': 1011,
#    'humidity': 74,
#    'dew_point': 19.08,
#    'uvi': 0,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 2.91,
#    'wind_deg': 84,
#    'wind_gust': 6.41,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769238000,
#    'temp': 23.21,
#    'feels_like': 23.6,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 18.99,
#    'uvi': 0,
#    'clouds': 3,
#    'visibility': 10000,
#    'wind_speed': 2.46,
#    'wind_deg': 87,
#    'wind_gust': 4.53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769241600,
#    'temp': 22.78,
#    'feels_like': 23.18,
#    'pressure': 1012,
#    'humidity': 79,
#    'dew_point': 18.96,
#    'uvi': 0,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 2.47,
#    'wind_deg': 89,
#    'wind_gust': 4.49,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769245200,
#    'temp': 23.11,
#    'feels_like': 23.49,
#    'pressure': 1013,
#    'humidity': 77,
#    'dew_point': 19,
#    'uvi': 0.25,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 2.03,
#    'wind_deg': 84,
#    'wind_gust': 5.74,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769248800,
#    'temp': 25.24,
#    'feels_like': 25.54,
#    'pressure': 1013,
#    'humidity': 66,
#    'dew_point': 18.48,
#    'uvi': 1.45,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 3.82,
#    'wind_deg': 78,
#    'wind_gust': 5.71,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769252400,
#    'temp': 27.47,
#    'feels_like': 28.11,
#    'pressure': 1014,
#    'humidity': 53,
#    'dew_point': 17.17,
#    'uvi': 4.1,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 4.41,
#    'wind_deg': 85,
#    'wind_gust': 5.71,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769256000,
#    'temp': 29.65,
#    'feels_like': 29.75,
#    'pressure': 1013,
#    'humidity': 44,
#    'dew_point': 16.11,
#    'uvi': 7.82,
#    'clouds': 4,
#    'visibility': 10000,
#    'wind_speed': 4.58,
#    'wind_deg': 83,
#    'wind_gust': 5.59,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769259600,
#    'temp': 31.67,
#    'feels_like': 31.34,
#    'pressure': 1013,
#    'humidity': 37,
#    'dew_point': 15.32,
#    'uvi': 11.5,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.64,
#    'wind_deg': 81,
#    'wind_gust': 5.28,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769263200,
#    'temp': 33.41,
#    'feels_like': 32.84,
#    'pressure': 1012,
#    'humidity': 32,
#    'dew_point': 14.68,
#    'uvi': 13.85,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.8,
#    'wind_deg': 78,
#    'wind_gust': 5.12,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769266800,
#    'temp': 34.75,
#    'feels_like': 33.94,
#    'pressure': 1011,
#    'humidity': 28,
#    'dew_point': 13.95,
#    'uvi': 13.86,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 4.49,
#    'wind_deg': 76,
#    'wind_gust': 4.95,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769270400,
#    'temp': 35.84,
#    'feels_like': 34.84,
#    'pressure': 1010,
#    'humidity': 25,
#    'dew_point': 13.18,
#    'uvi': 11.84,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 4.29,
#    'wind_deg': 78,
#    'wind_gust': 5.06,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769274000,
#    'temp': 36.65,
#    'feels_like': 35.52,
#    'pressure': 1009,
#    'humidity': 23,
#    'dew_point': 12.24,
#    'uvi': 8.27,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 4.2,
#    'wind_deg': 80,
#    'wind_gust': 5.35,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1769277600,
#    'temp': 37.03,
#    'feels_like': 35.62,
#    'pressure': 1008,
#    'humidity': 21,
#    'dew_point': 11.36,
#    'uvi': 4.49,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 4.15,
#    'wind_deg': 89,
#    'wind_gust': 5.53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1769090400,
#    'sunrise': 1769070618,
#    'sunset': 1769115412,
#    'moonrise': 1769081340,
#    'moonset': 1769126040,
#    'moon_phase': 0.13,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 33.28,
#     'min': 22.65,
#     'max': 37.21,
#     'night': 26.48,
#     'eve': 36.98,
#     'morn': 22.65},
#    'feels_like': {'day': 33.01, 'night': 26.48, 'eve': 34.74, 'morn': 23.03},
#    'pressure': 1010,
#    'humidity': 34,
#    'dew_point': 15.46,
#    'wind_speed': 7.92,
#    'wind_deg': 52,
#    'wind_gust': 12.88,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'clouds': 57,
#    'pop': 0,
#    'uvi': 13.75},
#   {'dt': 1769176800,
#    'sunrise': 1769157042,
#    'sunset': 1769201820,
#    'moonrise': 1769170620,
#    'moonset': 1769214960,
#    'moon_phase': 0.16,
#    'summary': 'You can expect partly cloudy in the morning, with clearing in the afternoon',
#    'temp': {'day': 32.75,
#     'min': 22.23,
#     'max': 37.24,
#     'night': 26.01,
#     'eve': 36.61,
#     'morn': 22.23},
#    'feels_like': {'day': 32.46, 'night': 26.01, 'eve': 34.76, 'morn': 22.41},
#    'pressure': 1011,
#    'humidity': 35,
#    'dew_point': 15.57,
#    'wind_speed': 6.66,
#    'wind_deg': 45,
#    'wind_gust': 11.86,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'clouds': 44,
#    'pop': 0,
#    'uvi': 13.93},
#   {'dt': 1769263200,
#    'sunrise': 1769243465,
#    'sunset': 1769288228,
#    'moonrise': 1769259960,
#    'moonset': 1769303880,
#    'moon_phase': 0.19,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 33.41,
#     'min': 22.78,
#     'max': 37.03,
#     'night': 25.89,
#     'eve': 36.06,
#     'morn': 22.78},
#    'feels_like': {'day': 32.84, 'night': 26.28, 'eve': 34.26, 'morn': 23.18},
#    'pressure': 1012,
#    'humidity': 32,
#    'dew_point': 14.68,
#    'wind_speed': 9.86,
#    'wind_deg': 41,
#    'wind_gust': 12.66,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 0,
#    'pop': 0.52,
#    'rain': 0.29,
#    'uvi': 13.86},
#   {'dt': 1769349600,
#    'sunrise': 1769329888,
#    'sunset': 1769374634,
#    'moonrise': 1769349420,
#    'moonset': 1769393100,
#    'moon_phase': 0.23,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 32.46,
#     'min': 23.47,
#     'max': 34.71,
#     'night': 29.74,
#     'eve': 31.44,
#     'morn': 23.84},
#    'feels_like': {'day': 33.15, 'night': 30.25, 'eve': 29.84, 'morn': 24.39},
#    'pressure': 1012,
#    'humidity': 41,
#    'dew_point': 17.85,
#    'wind_speed': 6.72,
#    'wind_deg': 63,
#    'wind_gust': 10.19,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 42,
#    'pop': 0.85,
#    'rain': 0.85,
#    'uvi': 9.55},
#   {'dt': 1769436000,
#    'sunrise': 1769416310,
#    'sunset': 1769461040,
#    'moonrise': 1769439120,
#    'moonset': 1769482560,
#    'moon_phase': 0.25,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 35.54,
#     'min': 23.23,
#     'max': 37.45,
#     'night': 26.79,
#     'eve': 30.57,
#     'morn': 23.23},
#    'feels_like': {'day': 35.24, 'night': 27.95, 'eve': 30.64, 'morn': 23.65},
#    'pressure': 1011,
#    'humidity': 29,
#    'dew_point': 15.13,
#    'wind_speed': 6.23,
#    'wind_deg': 62,
#    'wind_gust': 11.04,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 75,
#    'pop': 1,
#    'rain': 1.04,
#    'uvi': 14},
#   {'dt': 1769522400,
#    'sunrise': 1769502732,
#    'sunset': 1769547445,
#    'moonrise': 1769529060,
#    'moonset': 0,
#    'moon_phase': 0.3,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 27.44,
#     'min': 23.62,
#     'max': 31.48,
#     'night': 23.76,
#     'eve': 27.76,
#     'morn': 23.76},
#    'feels_like': {'day': 28.23, 'night': 24.31, 'eve': 28.62, 'morn': 24.23},
#    'pressure': 1014,
#    'humidity': 55,
#    'dew_point': 17.84,
#    'wind_speed': 5.4,
#    'wind_deg': 66,
#    'wind_gust': 10,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'chuva moderada',
#      'icon': '10d'}],
#    'clouds': 99,
#    'pop': 1,
#    'rain': 3.93,
#    'uvi': 5.39},
#   {'dt': 1769608800,
#    'sunrise': 1769589153,
#    'sunset': 1769633849,
#    'moonrise': 1769619240,
#    'moonset': 1769572380,
#    'moon_phase': 0.34,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 33.41,
#     'min': 22.41,
#     'max': 35.49,
#     'night': 25.13,
#     'eve': 30.28,
#     'morn': 22.51},
#    'feels_like': {'day': 33.19, 'night': 25.55, 'eve': 30.27, 'morn': 23.11},
#    'pressure': 1012,
#    'humidity': 34,
#    'dew_point': 15.6,
#    'wind_speed': 4.44,
#    'wind_deg': 79,
#    'wind_gust': 8.91,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.97,
#    'rain': 1.77,
#    'uvi': 6},
#   {'dt': 1769695200,
#    'sunrise': 1769675573,
#    'sunset': 1769720252,
#    'moonrise': 1769709540,
#    'moonset': 1769662500,
#    'moon_phase': 0.38,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 34.11,
#     'min': 22.82,
#     'max': 34.11,
#     'night': 23.54,
#     'eve': 27.38,
#     'morn': 22.82},
#    'feels_like': {'day': 34.42, 'night': 24.09, 'eve': 28.41, 'morn': 23.35},
#    'pressure': 1011,
#    'humidity': 35,
#    'dew_point': 16.47,
#    'wind_speed': 5.49,
#    'wind_deg': 77,
#    'wind_gust': 9.16,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 38,
#    'pop': 1,
#    'rain': 1.77,
#    'uvi': 6}]}

# %%
result["current"]["weather"][0]["description"]
# Out:
# 'algumas nuvens'

# %% [markdown]
# ## Funções que serão usadas pelo LLM

# %%
def get_weather(lat:float, lon:float, api_key=open_weather_key) -> str:

    """ 
    Essa função nos informa o clima  do ponto dado por 
    latitude=lat e longitude=lon no momento exato em que é chamada
    """

    if not api_key:
        return {"error": "OpenWeather api key not set"}
    
    url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
    )

    response = requests.get(url)
    result = json.loads(response.content)

    return f"O clima em lat={lat} e lon={lon}, região da {result["timezone"]}, é {result["current"]["weather"][0]["description"]}"

print(get_weather( -23.5475, -46.6361))
# Out:
# O clima em lat=-23.5475 e lon=-46.6361, região da America/Sao_Paulo, é nublado

# %%
def send_email_stup(to:str, subject:str, body:str) -> dict:
    """Stub simples: em prod troque por SendGrid/Mailgun/SMTP real."""
    return {"sent": True, "to": to, "subject": subject}

# %% [markdown]
# ## Schema para o modelo ( Function Calling )

# %%
functions = [
    {   
        "type": "function",
        "name": "get_weather",
        "description": "Retorna temperatura e descrição do tempo para uma cidade.",
        "parameters": {
            "type": "object",
            "properties": {
                "lat": {
                    "type": "number",
                    "minimum": -90,
                    "maximum": 90,
                    "description": "Latitude (ex: -3.171722)"},
                "lon": {
                    "type": "number",
                    "minimum":-180,
                    "maximum":180,
                    "description": "Longitude (ex: -38.5434)"},
                "api_key": {"type": "string"}
            },
            "required": ["lat", "lon"]
        }
    },
    {   
        "type": "function",
        "name": "send_email",
        "description": "Envia um email simples.",
        "parameters": {
            "type": "object",
            "properties": {
                "to": {"type": "string"},
                "subject": {"type": "string"},
                "body": {"type": "string"}
            },
            "required": ["to", "subject", "body"]
        }
    }
]

# %% [markdown]
# ## Workflow

# %%
input = (
    "Verifique o tempo em Fortaleza hoje. "
    "Se estiver chuvoso, envie um email para iran@example.com pedindo que leve guarda-chuva."
)

client_openai = OpenAI(api_key=openai_api_key)

response = client_openai.responses.parse(
    model="gpt-4.1-mini",
    input=input,
    temperature=0.0, 
    tools=functions
)

# %%
response
# Out:
# ParsedResponse[NoneType](id='resp_038696fdeac5dace006972a467a8ec819f847a8497cc7bc5d6', created_at=1769120871.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini-2025-04-14', object='response', output=[ParsedResponseFunctionToolCall(arguments='{"lat":-3.71722,"lon":-38.5434,"api_key":"demo"}', call_id='call_pBVfIt4wJTzu2bwSwsz0R8K3', name='get_weather', type='function_call', id='fc_038696fdeac5dace006972a4684c30819fb49bb416397ccedb', status='completed', parsed_arguments=None)], parallel_tool_calls=True, temperature=0.0, tool_choice='auto', tools=[FunctionTool(name='get_weather', parameters={'type': 'object', 'properties': {'lat': {'type': 'number', 'minimum': -90, 'maximum': 90, 'description': 'Latitude (ex: -3.171722)'}, 'lon': {'type': 'number', 'minimum': -180, 'maximum': 180, 'description': 'Longitude (ex: -38.5434)'}, 'api_key': {'type': 'string'}}, 'required': ['lat', 'lon', 'api_key'], 'additionalProperties': False}, strict=True, type='function', description='Retorna temperatura e descrição do tempo para uma cidade.'), FunctionTool(name='send_email', parameters={'type': 'object', 'properties': {'to': {'type': 'string'}, 'subject': {'type': 'string'}, 'body': {'type': 'string'}}, 'required': ['to', 'subject', 'body'], 'additionalProperties': False}, strict=True, type='function', description='Envia um email simples.')], top_p=1.0, background=False, completed_at=1769120872.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=160, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=32, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=192), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)

# %% [markdown]
# A percepção que precisamos ter aqui é que quando o Function Calling entra em ação, o modelo para de _gerar texto livre_ e passa a gerar _*respostas estruturadas*_.
#
# Em pipelines de decisão automatizada, a saída do modelo deve ser estruturada e validável. Respostas em texto livre não são adequadas como interface de decisão, pois introduzem ambiguidade, dificultam validação e tornam o sistema não determinístico.
#
#
# * Texto livre → *output* para *humanos*
# * Output estruturado → *input* para *sistemas*
